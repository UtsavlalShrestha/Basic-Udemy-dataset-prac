# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\shres\OneDrive\Desktop\udemy pandas\file.csv")

# %%
df.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %% [markdown]
# ### Questions

# %%
# 1) different subjects being offered
df.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %%
len(df.subject.unique())
# Out:
# 4

# %%
# 2) Subject with max courses
df['subject'].value_counts().head(1)
# Out:
# subject
# Web Development    1200
# Name: count, dtype: int64

# %%
# 3) Courses free of cost
df[df['is_paid']==False][['course_title']]
# Out:
#                                            course_title
# 41          5 lecciones que todo guitarrista debe tomar
# 49    7 Ways A Beginner Guitarist Can Sound Better, ...
# 57    A beginner`s guide to fingerpicking and strumm...
# 67                               A how to guide in HTML
# 74    ¡Triunfar en La Bolsa de Valores No Requiere d...
# ...                                                 ...
# 3620  WordPress in under an hour - Create/manage you...
# 3638                     Wordpress Website Mastery 2017
# 3652  Write quicker HTML5 and CSS 3; productivity ha...
# 3674  Your First 10 Guitar Lessons - Learn how to pl...
# 3680  Zoho Books Gestion Financière d'Entreprise pas...
#
# [310 rows x 1 columns]

# %%
# or arko way
df.query('is_paid == False')['course_title'].count()
# Out:
# 310

# %%
# 4) courses which are paid
df[df['is_paid']==True][['course_title']].count()
# Out:
# course_title    3372
# dtype: int64

# %%
# 5) Top seller course and least seller
df.sort_values('num_subscribers', ascending =False).head(1)
# Out:
#       course_id                          course_title  is_paid price  \
# 2230      41295  Learn HTML5 Programming From Scratch    False  Free
#
#       num_subscribers  num_reviews  num_lectures       level content_duration  \
# 2230           268923         8629            45  All Levels       10.5 hours
#
#        published_timestamp          subject
# 2230  2013-02-14T07:03:41Z  Web Development

# %%
# least seller
df.sort_values('num_subscribers', ascending  = True).head(1)
# Out:
#      course_id                   course_title  is_paid price  num_subscribers  \
# 649    1233314  Building a Balanced Scorecard     True    50                0
#
#      num_reviews  num_lectures               level content_duration  \
# 649            0            11  Intermediate Level          2 hours
#
#       published_timestamp           subject
# 649  2017-07-03T21:38:22Z  Business Finance

# %%
# 6) Courses on graphic design with price below 100
df[(df['subject']=='Graphic Design') & (df['price'] < 100)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[116], line 2
#       1 # 6) Courses on graphic design with price below 100
# ----> 2 df[(df['subject']=='Graphic Design') & (df['price'] < 100)]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
# ...

# %%
df.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
#price is object 
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# %%
df.dtypes
# Out:
# course_id                int64
# course_title            object
# is_paid                   bool
# price                  float64
# num_subscribers          int64
# num_reviews              int64
# num_lectures             int64
# level                   object
# content_duration        object
# published_timestamp     object
# subject                 object
# dtype: object

# %%
df[(df['subject']=='Graphic Design') & (df['price'] < 100)]
# Out:
#       course_id                                       course_title  is_paid  \
# 8        206592  :::Beginners Guide To Creating Amazing Images ...     True
# 20      1165268  15  Motion Graphic Elements in After Effect (S...     True
# 35      1164876  3DS MAX - Learn 3Ds MAX tutorial for Beginners...     True
# 39       599652                     48 Logo Designs and Techniques     True
# 52       794036       8 Stunden professionelles Cinema 4D Training     True
# ...         ...                                                ...      ...
# 3568     133968                 Web Elements Design With Photoshop     True
# 3588    1131780  Whiteboard Animation, Beginner To Expert - In ...     True
# 3639    1122306         Wordpress: Comment utiliser le thème FABLE     True
# 3671     144222  YOU can Draw, Shade and Paint a Mixed Media Gi...     True
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
# 8) List courses related to Python
df[df['course_title'].str.contains('Python', case=False)]
# Out:
#       course_id                                       course_title  is_paid  \
# 216      599504  Advanced Scalable Python Web Development Using...     True
# 777       47963  Coding for Entrepreneurs: Learn Python, Django...     True
# 814      631128  Complete Python Web Course: Build 8 Python Web...     True
# 842      186096  Core: A Web App Reference Guide for Django, Py...     True
# 1400     394832  Fun and creative web engineering with Python a...    False
# 1932    1038538            Introduction to QGIS Python Programming     True
# 1969     902888          Investment Portfolio Analysis with Python     True
# 2294     391546        Learn Python and Django: Payment Processing     True
# 2295    1063722            Learn Python Django - A Hands-On Course     True
# 2341     546848  Learn to code in Python and learn Adobe Photos...     True
# 2906     368340    Professional Python Web Development Using Flask     True
# ...

# %%
# 9) Courses published on 2015
df['published_timestamp'] = pd.to_datetime(df['published_timestamp'])

# %%
df['year'] = df['published_timestamp'].dt.year

# %%
df.query('year ==2015')
# Out:
#       course_id                                       course_title  is_paid  \
# 10       591880  1 - Concepts of Statistics For Beginners Step ...     True
# 16       302450        10 Numbers Every Business Owner Should Know     True
# 19       384928  101 Blues riffs - learn how the harmonica supe...     True
# 23       550842  16 Guitar Chords to Jam With - (Beginner - Int...     True
# 26       486240      2 Easy Steps To Investment And Avoiding Traps     True
# ...         ...                                                ...      ...
# 3675     551170                         Your First Course on Piano     True
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
#
# ...

# %%
df.drop(columns ='year')
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
# 10) Max number of courses for each subscribers

df.groupby('level')['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64
